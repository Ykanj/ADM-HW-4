# %%
import pandas as pd

# %% [markdown]
# ### Exploratory Data Analysis
#
# Let us start off by importing our dataset and taking a look at it to understand the data.

# %%
netflix = pd.read_csv(r"Data\vodclickstream_uk_movies_03.csv")                                          

print(len(netflix["title"].unique()), len(netflix["movie_id"].unique()))            # These two columns are not equal in length, ~500 items have
                                                                                    # the same title but are different  
netflix = netflix.sort_values(["user_id", "movie_id", "datetime"])
netflix.head(50)                                                                    # Some movies also have the same user clicking on the same move
                                                                                    # on the exact same datetime, with one being 0 seconds and the 
                                                                                    # other being more than 0, this will be counted as one
# Out:
# 7925 8472
#         Unnamed: 0             datetime  duration  \
# 223802      282575  2017-12-05 20:39:15       0.0
# 89781       148554  2017-05-30 20:36:34       0.0
# 102939      161712  2017-06-18 20:38:02       0.0
# 102994      161767  2017-06-18 20:44:27       0.0
# 103016      161789  2017-06-18 20:44:27       0.0
# 103035      161808  2017-06-18 20:44:27       0.0
# 103059      161832  2017-06-18 20:44:27       0.0
# 103082      161855  2017-06-18 20:44:27       0.0
# 103110      161883  2017-06-18 20:44:27     600.0
# 103145      161918  2017-06-18 20:44:27       0.0
# 103171      161944  2017-06-18 20:54:27    6736.0
# 101603      160376  2017-06-16 23:21:50    1988.0
# 102839      161612  2017-06-17 19:38:19    1032.0
# 102394      161167  2017-06-17 21:45:26    1367.0
# 109109      167882  2017-06-26 13:18:08    6226.0
# 84713       143486  2017-05-24 07:29:07       0.0
# 84324       143097  2017-05-24 15:30:16    4279.0
# ...

# %% [markdown]
# ### Question 1: Recommendation System
#
# We will attempt to implement a recommendation system by identifying similar users' preferences and recommending movies they watch to the study user.

# %% [markdown]
# #### 1.1 Top 10 movies per user

# %% [markdown]
# Lets work on creating a dataframe of sorted user IDs, and their favorite movies from 1st to 10th, based on number of clicks, two clicks on the same exact datetime will be counted as one. Ties will be split by duration.

# %%
for user in netflix["user_id"].unique():
